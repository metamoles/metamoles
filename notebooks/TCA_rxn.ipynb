# %%
import numpy as np
import pandas as pd
import math
import ast

# %% [markdown]
# # Additional task
# Finding the pathway in central metabolites --- e.g. TCA cycle

# %%
TCA_raw = pd.read_csv('../datasets/TCA_pathway.csv', names = ['Col'])

# %%
TCA_raw.tail(50)
# Out:
#                                                    Col
# 64                                     CREDITS - caspi
# 65   DBLINKS - (ECOCYC "TCA" NIL |paley| 3392397157...
# 66   DBLINKS - (ARACYC "TCA" NIL |green| 3381011399...
# 67                        ENZYMES-NOT-USED - CPLX0-251
# 68                       IN-PATHWAY - TCA-GLYOX-BYPASS
# 69                       KEY-REACTIONS - ISOCITDEH-RXN
# 70   KEY-REACTIONS - MALATE-DEHYDROGENASE-ACCEPTOR-RXN
# 71                      KEY-REACTIONS - SUCCCOASYN-RXN
# 72   PATHWAY-LINKS - (ACETYL-COA (|Fatty-Acid-Degra...
# 73          PREDECESSORS - ("FUMHYDR-RXN" "RXN-14971")
# 74       PREDECESSORS - ("RXN-14971" "SUCCCOASYN-RXN")
# 75      PREDECESSORS - ("CITSYN-RXN" "MALATE-DEH-RXN")
# 76     PREDECESSORS - ("MALATE-DEH-RXN" "FUMHYDR-RXN")
# 77   PREDECESSORS - ("SUCCCOASYN-RXN" "2OXOGLUTARAT...
# 78   PREDECESSORS - ("2OXOGLUTARATEDEH-RXN" "ISOCIT...
# 79   PREDECESSORS - ("ISOCITDEH-RXN" "ACONITATEHYDR...
# 80   PREDECESSORS - ("ACONITATEHYDR-RXN" "ACONITATE...
# 81   PREDECESSORS - ("ACONITATEDEHYDR-RXN" "CITSYN-...
# 82   PREDECESSORS - ("MALATE-DEHYDROGENASE-ACCEPTOR...
# 83   PREDECESSORS - ("CITSYN-RXN" "MALATE-DEHYDROGE...
# 84   REACTION-LAYOUT - (RXN-14971 (:LEFT-PRIMARIES ...
# 85   REACTION-LAYOUT - (MALATE-DEH-RXN (:LEFT-PRIMA...
# 86   REACTION-LAYOUT - (ISOCITDEH-RXN (:LEFT-PRIMAR...
# 87   REACTION-LAYOUT - (MALATE-DEHYDROGENASE-ACCEPT...
# 88   REACTION-LAYOUT - (ACONITATEDEHYDR-RXN (:LEFT-...
# 89   REACTION-LAYOUT - (CITSYN-RXN (:LEFT-PRIMARIES...
# 90   REACTION-LAYOUT - (ACONITATEHYDR-RXN (:LEFT-PR...
# 91   REACTION-LAYOUT - (2OXOGLUTARATEDEH-RXN (:LEFT...
# 92   REACTION-LAYOUT - (SUCCCOASYN-RXN (:LEFT-PRIMA...
# 93   REACTION-LAYOUT - (FUMHYDR-RXN (:LEFT-PRIMARIE...
# 94                           REACTION-LIST - RXN-14971
# 95                      REACTION-LIST - MALATE-DEH-RXN
# 96                       REACTION-LIST - ISOCITDEH-RXN
# 97   REACTION-LIST - MALATE-DEHYDROGENASE-ACCEPTOR-RXN
# 98                 REACTION-LIST - ACONITATEDEHYDR-RXN
# 99                          REACTION-LIST - CITSYN-RXN
# 100                  REACTION-LIST - ACONITATEHYDR-RXN
# 101               REACTION-LIST - 2OXOGLUTARATEDEH-RXN
# 102                     REACTION-LIST - SUCCCOASYN-RXN
# 103                        REACTION-LIST - FUMHYDR-RXN
# 104                                  SPECIES - TAX-354
# 105                               SPECIES - TAX-511145
# 106                  SUPER-PATHWAYS - TCA-GLYOX-BYPASS
# 107                SYNONYMS - tricarboxylic acid cycle
# 108                       SYNONYMS - citric acid cycle
# 109                             SYNONYMS - Krebs cycle
# 110               SYNONYMS - Szent-Gyorgyi-Krebs cycle
# 111                            TAXONOMIC-RANGE - TAX-2
# 112                         TAXONOMIC-RANGE - TAX-2157
# 113                                                 //

# %%
TCA_rxn = []
rxn_str = 'REACTION-LIST'
for index, row in TCA_raw[90:].iterrows():
    if row['Col'][:len(rxn_str)] == rxn_str:
        TCA_rxn.append(row['Col'][(len(rxn_str)+3):])

# %%
TCA_rxn
# Out:
# ['RXN-14971',
#  'MALATE-DEH-RXN',
#  'ISOCITDEH-RXN',
#  'MALATE-DEHYDROGENASE-ACCEPTOR-RXN',
#  'ACONITATEDEHYDR-RXN',
#  'CITSYN-RXN',
#  'ACONITATEHYDR-RXN',
#  '2OXOGLUTARATEDEH-RXN',
#  'SUCCCOASYN-RXN',
#  'FUMHYDR-RXN']

# %%
def recover_list(df, column):
    """This function will recover a list formatted string read from .csv into a list"""
    assert type(df[column][0]) != type([]), "TypeError: The data type is already a list, it should not be converted again"
    replacement = []
    for index, row in df.iterrows():
        
        data = []
        
        if type(row[column]) == type('string'):
            data = ast.literal_eval(row[column])
        else:
            pass
        replacement.append(data)
    df[column] = replacement
    return

# %%
df_cpd = pd.read_csv('df_cpd.csv', index_col = 0)
df_cpd = df_cpd.set_index(keys ='UNIQUE-ID')

df_rxn = pd.read_csv('parsed_rxns.csv', index_col = 0)
df_rxn = df_rxn.set_index(keys = 'UNIQUE-ID')

# Change PubChemID into int type in df_cpd
PubChemID_int = df_cpd['PubChemID'].fillna(0).astype(int)
df_cpd['PubChemID'] = PubChemID_int

# Recover list format of df_rxn
rxn_list_fix = ['EC-NUMBER', 'ERXN-NUMBER', 'SUBSTRATES', 'PRODUCTS']
for col in rxn_list_fix:
    recover_list(df_rxn, col)

# %%
df_TCA = pd.DataFrame({'ERXN-NUMBER': [],
                      'EC-NUMBER': [],
                      'SUBSTRATES': [],
                      'PRODUCTS': [],
                      'GIBBS': []})
for item in TCA_rxn:
    print(item, '\n', df_rxn.loc[item], '\n')
    df_TCA.loc[item] = df_rxn.loc[item]
# Out:
# RXN-14971
#  ERXN-NUMBER    [ENZRXN-24875, ENZRXN-24874, ENZRXN-12464]
# EC-NUMBER                                    [EC-1.3.5.1]
# SUBSTRATES                            [ETR-Quinones, SUC]
# PRODUCTS                               [ETR-Quinols, FUM]
# GIBBS                                            -5.04225
# Name: RXN-14971, dtype: object
#
# MALATE-DEH-RXN
#  ERXN-NUMBER    [MALATE-DEH-ENZRXN, ENZRXN-22204, ENZRXN66-196...
# EC-NUMBER                                          [EC-1.1.1.37]
# SUBSTRATES                                            [MAL, NAD]
# PRODUCTS                         [OXALACETIC_ACID, NADH, PROTON]
# GIBBS                                                    4.46176
# Name: MALATE-DEH-RXN, dtype: object
#
# ISOCITDEH-RXN
#  ERXN-NUMBER    [ISOCITDEH-ENZRXN, ENZRXN3O-1406, ENZRXN-12349...
# EC-NUMBER                                          [EC-1.1.1.42]
# SUBSTRATES                          [THREO-DS-ISO-CITRATE, NADP]
# PRODUCTS                [2-KETOGLUTARATE, CARBON-DIOXIDE, NADPH]
# GIBBS                                                   0.375854
# Name: ISOCITDEH-RXN, dtype: object
#
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN
#  ERXN-NUMBER                     [ENZRXN0-282]
# EC-NUMBER                        [EC-1.1.5.4]
# SUBSTRATES                [ETR-Quinones, MAL]
# PRODUCTS       [ETR-Quinols, OXALACETIC_ACID]
# GIBBS                                -14.9423
# Name: MALATE-DEHYDROGENASE-ACCEPTOR-RXN, dtype: object
#
# ACONITATEDEHYDR-RXN
#  ERXN-NUMBER    [ACONITATEDEHYDR-ENZRXN, ACONITATEDEHYDRB-ENZR...
# EC-NUMBER                                                     []
# SUBSTRATES                                                 [CIT]
# PRODUCTS                                  [CIS-ACONITATE, WATER]
# GIBBS                                                      3.353
# Name: ACONITATEDEHYDR-RXN, dtype: object
#
# CITSYN-RXN
#  ERXN-NUMBER    [CITSYN-ENZRXN, ENZRXN0-7594, ENZRXN3O-1609, E...
# EC-NUMBER                              [EC-2.3.3.16, EC-2.3.3.1]
# SUBSTRATES                  [ACETYL-COA, WATER, OXALACETIC_ACID]
# PRODUCTS                                     [CIT, CO-A, PROTON]
# GIBBS                                                   -10.5153
# Name: CITSYN-RXN, dtype: object
#
# ACONITATEHYDR-RXN
#  ERXN-NUMBER    [ACONITATEHYDR-ENZRXN, ACONITATEHYDRB-ENZRXN, ...
# EC-NUMBER                                                     []
# SUBSTRATES                                [CIS-ACONITATE, WATER]
# PRODUCTS                                  [THREO-DS-ISO-CITRATE]
# GIBBS                                                     -3.133
# Name: ACONITATEHYDR-RXN, dtype: object
#
# 2OXOGLUTARATEDEH-RXN
#  ERXN-NUMBER    [2OXOGLUTARATEDEH-ENZRXN, ENZRXN-23162, ENZRXN...
# EC-NUMBER                                          [EC-1.2.1.M9]
# SUBSTRATES                          [2-KETOGLUTARATE, CO-A, NAD]
# PRODUCTS                         [SUC-COA, CARBON-DIOXIDE, NADH]
# GIBBS                                                   -11.3664
# Name: 2OXOGLUTARATEDEH-RXN, dtype: object
#
# SUCCCOASYN-RXN
#  ERXN-NUMBER    [SUCCCOASYN-ENZRXN, ENZRXN-22640, ENZRXN-22263...
# EC-NUMBER                                           [EC-6.2.1.5]
# SUBSTRATES                                      [SUC, CO-A, ATP]
# PRODUCTS                                      [SUC-COA, ADP, Pi]
# GIBBS                                                   -1.05408
# Name: SUCCCOASYN-RXN, dtype: object
#
# FUMHYDR-RXN
#  ERXN-NUMBER    [FUMARC-ENZRXN, ENZRXN0-8343, ENZRXN0-8344, FU...
# EC-NUMBER                                           [EC-4.2.1.2]
# SUBSTRATES                                                 [MAL]
# PRODUCTS                                            [FUM, WATER]
# GIBBS                                                   0.613007
# Name: FUMHYDR-RXN, dtype: object

# %%
df_TCA.to_csv('df_TCA.csv')
df_TCA
# Out:
#                                                                          ERXN-NUMBER  \
# RXN-14971                                 [ENZRXN-24875, ENZRXN-24874, ENZRXN-12464]
# MALATE-DEH-RXN                     [MALATE-DEH-ENZRXN, ENZRXN-22204, ENZRXN66-196...
# ISOCITDEH-RXN                      [ISOCITDEH-ENZRXN, ENZRXN3O-1406, ENZRXN-12349...
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN                                      [ENZRXN0-282]
# ACONITATEDEHYDR-RXN                [ACONITATEDEHYDR-ENZRXN, ACONITATEDEHYDRB-ENZR...
# CITSYN-RXN                         [CITSYN-ENZRXN, ENZRXN0-7594, ENZRXN3O-1609, E...
# ACONITATEHYDR-RXN                  [ACONITATEHYDR-ENZRXN, ACONITATEHYDRB-ENZRXN, ...
# 2OXOGLUTARATEDEH-RXN               [2OXOGLUTARATEDEH-ENZRXN, ENZRXN-23162, ENZRXN...
# SUCCCOASYN-RXN                     [SUCCCOASYN-ENZRXN, ENZRXN-22640, ENZRXN-22263...
# FUMHYDR-RXN                        [FUMARC-ENZRXN, ENZRXN0-8343, ENZRXN0-8344, FU...
#
#                                                    EC-NUMBER  \
# RXN-14971                                       [EC-1.3.5.1]
# MALATE-DEH-RXN                                 [EC-1.1.1.37]
# ISOCITDEH-RXN                                  [EC-1.1.1.42]
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN               [EC-1.1.5.4]
# ACONITATEDEHYDR-RXN                                       []
# CITSYN-RXN                         [EC-2.3.3.16, EC-2.3.3.1]
# ACONITATEHYDR-RXN                                         []
# 2OXOGLUTARATEDEH-RXN                           [EC-1.2.1.M9]
# SUCCCOASYN-RXN                                  [EC-6.2.1.5]
# FUMHYDR-RXN                                     [EC-4.2.1.2]
#
#                                                              SUBSTRATES  \
# RXN-14971                                           [ETR-Quinones, SUC]
# MALATE-DEH-RXN                                               [MAL, NAD]
# ISOCITDEH-RXN                              [THREO-DS-ISO-CITRATE, NADP]
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN                   [ETR-Quinones, MAL]
# ACONITATEDEHYDR-RXN                                               [CIT]
# CITSYN-RXN                         [ACETYL-COA, WATER, OXALACETIC_ACID]
# ACONITATEHYDR-RXN                                [CIS-ACONITATE, WATER]
# 2OXOGLUTARATEDEH-RXN                       [2-KETOGLUTARATE, CO-A, NAD]
# SUCCCOASYN-RXN                                         [SUC, CO-A, ATP]
# FUMHYDR-RXN                                                       [MAL]
#
#                                                                    PRODUCTS  \
# RXN-14971                                                [ETR-Quinols, FUM]
# MALATE-DEH-RXN                              [OXALACETIC_ACID, NADH, PROTON]
# ISOCITDEH-RXN                      [2-KETOGLUTARATE, CARBON-DIOXIDE, NADPH]
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN            [ETR-Quinols, OXALACETIC_ACID]
# ACONITATEDEHYDR-RXN                                  [CIS-ACONITATE, WATER]
# CITSYN-RXN                                              [CIT, CO-A, PROTON]
# ACONITATEHYDR-RXN                                    [THREO-DS-ISO-CITRATE]
# 2OXOGLUTARATEDEH-RXN                        [SUC-COA, CARBON-DIOXIDE, NADH]
# SUCCCOASYN-RXN                                           [SUC-COA, ADP, Pi]
# FUMHYDR-RXN                                                    [FUM, WATER]
#
#                                        GIBBS
# RXN-14971                          -5.042252
# MALATE-DEH-RXN                      4.461761
# ISOCITDEH-RXN                       0.375854
# MALATE-DEHYDROGENASE-ACCEPTOR-RXN -14.942260
# ACONITATEDEHYDR-RXN                 3.352997
# CITSYN-RXN                        -10.515259
# ACONITATEHYDR-RXN                  -3.132996
# 2OXOGLUTARATEDEH-RXN              -11.366394
# SUCCCOASYN-RXN                     -1.054077
# FUMHYDR-RXN                         0.613007
