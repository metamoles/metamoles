# %% [markdown]
# ### Structure Analysis
#
# This notebook aim to study simple RDKit usage and try to generate code block for assignment of reaction center

# %%
import numpy as pd
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Descriptors import MolWt

# %%
def count_C(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 6)
def count_O(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 8)
def count_N(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 7)
def count_P(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 15)
def count_S(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 16)
def count_X(mol):
    return sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() == 9 or atom.GetAtomicNum() == 17 or atom.GetAtomicNum() == 35 or atom.GetAtomicNum() == 53)
def count_H(mol):
    H = 0
    for i in range(mol.GetNumAtoms()):
        H += mol.GetAtomWithIdx(i).GetTotalNumHs(includeNeighbors=True)
    return H

def DoU(mol):
    C = count_C(mol)
    H = count_H(mol)
    O = count_O(mol)
    N = count_N(mol)
    P = count_P(mol)
    S = count_S(mol)
    X = count_X(mol)
    return int((2*C+2+N+P-X-H)/2)

from rdkit.Chem.Descriptors import MolWt

def cpd_inform(SMILES):
    
    """A function for getting compound information from SMILES string
    it received a SMILES string and return a dictionary of information consisted of number of C, H, O , N, P, S, X, Degree of Unsaturation and Molecular Weight"""
    info = {}
    mol = Chem.MolFromSmiles(SMILES)
    info['n_C'] = count_C(mol)
    info['n_H'] = count_H(mol)
    info['n_O'] = count_O(mol)
    info['n_N'] = count_N(mol)
    info['n_P'] = count_P(mol)
    info['n_S'] = count_S(mol)
    info['n_X'] = count_X(mol)
    info['DoU'] = DoU(mol)
    info['MW'] = MolWt(mol)
    
    return info

# %%
df_master = pd.read_csv('../../../big-datasets/selected_with_smiles.csv')

# %%
df_master = df_master[['enzyme', 'product', 'reacts', 'PubChemID', 'SMILES']]

# %%
# _info = pd.DataFrame(np.empty(2,2), columns=['n_C', 'n_H'])
# make it into a function that return dictionary with n_C and others as keys      

l_C = []
l_H = []
l_O = []
l_N = []
l_P = []
l_S = [] 
l_X = []
l_DoU = []
l_MW = []

for index in range(df_master.shape[0]):
    mol = Chem.MolFromSmiles(df_master['SMILES'][index])
    l_C.append(count_C(mol))
    l_H.append(count_H(mol))
    l_O.append(count_O(mol))
    l_N.append(count_N(mol))
    l_P.append(count_P(mol))
    l_S.append(count_S(mol))
    l_X.append(count_X(mol))
    l_DoU.append(DoU(mol))
    l_MW.append(MolWt(mol))

# %%
df_info = pd.DataFrame()
df_info['n_C'] = l_C
df_info['n_H'] = l_H
df_info['n_O'] = l_O
df_info['n_N'] = l_N
df_info['n_P'] = l_P
df_info['n_S'] = l_S
df_info['n_X'] = l_X
df_info['n_DoU'] = l_DoU
df_info['MW'] = l_MW

df_info
# Out:
#        n_C  n_H  n_O  n_N  n_P  n_S  n_X  n_DoU        MW
# 0       10   18    2    0    0    0    0      2   170.252
# 1        9   10    1    0    0    0    0      5   134.178
# 2        8    7    3    0    0    0    0      5   151.141
# 3        0    0    0    0    0    0    1      0    35.453
# 4       20   28   19    3    2    0    0      9   676.394
# 5       21   30    4    0    0    0    0      7   346.467
# 6       16   19    3    1    0    0    0      8   273.332
# 7        0    2    0    0    0    1    0      0    34.083
# 8        0    0    3    0    0    1    0      1    80.064
# 9       11   19    6    4    0    0    0      4   303.295
# 10      21   36    1    0    0    0    0      4   304.518
# 11       6    6    2    0    0    0    0      4   110.112
# 12      10    8    2    0    0    0    0      7   160.172
# 13       4    9    2    1    0    0    0      1   103.121
# 14      17   22   18    3    2    0    0      9   618.314
# 15      10   18    5    4    0    1    0      4   306.344
# 16       9   10    2    0    0    0    0      5   150.177
# 17       0    1    0    0    0    0    0      0     2.016
# 18      17   24    4    1    0    0    0      6   306.382
# 19       5    4    5    0    0    0    0      4   144.082
# 20       9   12    5    2    0    0    0      5   228.204
# 21       5    4    5    0    0    0    0      4   144.082
# 22      10   10    1    2    0    0    0      7   174.203
# 23      23   48   15    4    0    0    0      2   620.650
# 24      40   56    0    0    0    0    0     13   536.888
# 25       6   11    7    0    0    0    0      1   195.147
# 26       9    7    0    1    0    0    0      7   129.162
# 27       5    4    5    0    0    0    0      4   144.082
# 28      62   88   14   13    1    0    0     26  1329.370
# 29      17   22    6    4    0    0    0      9   378.385
# ...    ...  ...  ...  ...  ...  ...  ...    ...       ...
# 16981   35   56   17    7    3    1    0     13   971.854
# 16982    3    7    6    0    1    0    0      1   170.057
# 16983    6    8    5    0    0    0    0      3   160.125
# 16984   35   52   19    7    3    1    0     15   999.820
# 16985   15   12    5    0    0    0    0     10   272.256
# 16986    8    9    3    1    0    0    0      5   167.164
# 16987    4    9    1    1    0    0    0      1    87.122
# 16988    5    6    1    0    0    1    0      3   114.169
# 16989   31   54    9    1    0    0    0      5   584.771
# 16990    1    4    1    0    0    0    0      0    32.042
# 16991   31   54    9    1    0    0    0      5   584.771
# 16992    1    0    1    1    0    0    0      2    42.017
# 16993   52   80    2    0    0    0    0     13   737.210
# 16994   30   48    2    0    0    0    0      7   440.712
# 16995   15   19   18    2    2    0    0      8   577.261
# 16996    6   12    6    0    0    0    0      1   180.156
# 16997    4    9    3    1    0    0    0      1   119.120
# 16998   10   12    9    5    2    0    0      8   408.180
# 16999   12   16    3    0    0    0    0      5   208.257
# 17000    5    9    2    1    0    0    0      2   115.132
# 17001    6    5    2    1    0    0    0      5   123.111
# 17002   40   62   26    9    2    0    0     15  1146.921
# 17003   21   26   17    7    3    0    0     14   741.393
# 17004    6    8   18    0    4    0    0      5   492.008
# 17005    8    7    2    1    0    0    0      6   149.149
# 17006   60   97    7    0    2    0    0     13   992.377
# 17007    6    0    1    0    0    0    5      4   265.330
# 17008    6    8    2    0    0    0    0      3   112.128
# 17009   53   82    3    0    0    0    0     13   767.236
# 17010   10    8    6    0    0    0    0      7   224.168
#
# [17011 rows x 9 columns]

# %%
df_master
# Out:
#                                               SMILES
# 0         C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)O)O)O)O
# 1    C([C@@H]1[C@@H]([C@@H]([C@H]([C@H](O1)O)O)O)O)O
# 2               C([C@H]([C@H]([C@@H](C(=O)CO)O)O)O)O
# 3  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...

# %%
df_result = pd.concat([df_master, df_info], axis=1)
df_result
# Out:
#                enzyme                                  product  reacts  \
# 0        EC-1.1.1.321                                  CPD-685     1.0
# 1        EC-1.1.1.111                                1-INDANOL     1.0
# 2       EC-1.21.99.M2                   4-HYDROXYPHENYLACETATE     1.0
# 3       EC-1.21.99.M2                                      CL-     1.0
# 4         EC-1.3.1.97                     UDP-N-ACETYLMURAMATE     1.0
# 5        EC-1.14.15.5                           CORTICOSTERONE     1.0
# 6       EC-1.14.19.50                                CPD-19421     1.0
# 7          EC-1.8.2.4                                       HS     1.0
# 8          EC-1.8.2.4                                      SO3     1.0
# 9         EC-1.5.1.18                                  CPD-308     1.0
# 10       EC-1.1.1.150                            PREGNAN-21-OL     1.0
# 11      EC-1.14.14.26                                  CPD-623     1.0
# 12      EC-1.13.11.55                      NAPHTHALENE-12-DIOL     1.0
# 13         EC-1.5.3.1                         DIMETHYL-GLYCINE     1.0
# 14       EC-1.1.1.334       UDP-N-ACETYL-2-AMINO-D-GLUCURONATE     1.0
# 15        EC-1.8.1.15                                 CPD-6401     1.0
# 16       EC-1.1.1.320                                CPD-15061     1.0
# 17        EC-1.12.2.1                        HYDROGEN-MOLECULE     1.0
# 18      EC-1.14.20.12                                 CPD-2202     1.0
# 19      EC-1.14.20.12                          2-KETOGLUTARATE     1.0
# 20       EC-1.14.11.1                             DEOXYURIDINE     1.0
# 21       EC-1.14.11.1                          2-KETOGLUTARATE     1.0
# 22     EC-1.14.14.M35                    INDOLE-3-ACETALDOXIME     1.0
# 23         EC-1.1.2.9                                CPD-14187     1.0
# 24        EC-1.5.1.M1                                CPD1F-129     1.0
# 25        EC-1.1.1.38                               L-GULONATE     1.0
# 26       EC-1.3.99.14                             ISOQUINOLINE     1.0
# 27      EC-1.14.11.57                          2-KETOGLUTARATE     1.0
# 28        EC-1.16.1.3                             COB-I-ALAMIN     1.0
# 29        EC-1.5.1.40                                  CPD-316     1.0
# ...               ...                                      ...     ...
# 16981    EC-2.1.1.259                                CPD-19147     0.0
# 16982    EC-2.3.1.253                  SN-GLYCEROL-1-PHOSPHATE     0.0
# 16983      EC-2.3.1.9                                  CPD-547     0.0
# 16984    EC-4.2.3.120                                CPD-11527     0.0
# 16985     EC-2.7.1.78                    2-HYDROXYISOFLAVANONE     0.0
# 16986   EC-1.14.14.72                                PYRIDOXAL     0.0
# 16987     EC-1.3.1.11                   2-METHYLPROPANAL-OXIME     0.0
# 16988     EC-2.5.1.41                                CPD-14758     0.0
# 16989     EC-1.17.4.2                                CPD-15946     0.0
# 16990    EC-1.1.1.175                                    METOH     0.0
# 16991   EC-1.14.14.35                                CPD-15946     0.0
# 16992     EC-4.2.1.73                                   CPD-69     0.0
# 16993     EC-2.4.1.14       2-METHYL-6-SOLANYL-14-BENZOQUINONE     0.0
# 16994    EC-1.3.99.19                      INDOLE_ACETALDEHYDE     0.0
# 16995    EC-1.1.1.366                          UDP-GLUCURONATE     0.0
# 16996     EC-2.3.1.31                                 TAGATOSE     0.0
# 16997   EC-1.14.14.76                         L-ALLO-THREONINE     0.0
# 16998   EC-1.13.11.11                                     DADP     0.0
# 16999     EC-1.16.1.6    BENZYL-2R3S-2-METHYL-3-HYDROXYBUTANOA     0.0
# 17000     EC-1.4.3.16                                      PRO     0.0
# 17001  EC-1.14.14.132                              BENZENE-NO2     0.0
# 17002    EC-2.4.1.176                                       C3     0.0
# 17003     EC-1.15.1.1                                CPD-18085     0.0
# 17004    EC-3.1.1.100                                 CPD-6781     0.0
# 17005    EC-2.7.1.175                                CPD-14590     0.0
# 17006      EC-2.7.7.5                                 CPD-9650     0.0
# 17007    EC-1.1.1.286                        PENTACHLOROPHENOL     0.0
# 17008    EC-1.14.11.9                                  CPD-288     0.0
# 17009      EC-1.9.3.1  2-HEXAPRENYL-3-METHYL-6-METHOXY-14-BENZ     0.0
# 17010     EC-2.7.1.71                               CHORISMATE     0.0
#
#        PubChemID                                             SMILES  n_C  n_H  \
# 0        5363397                                 CC(=CCO)CCC=C(C)CO   10   18
# 1          22819                                  C1CC2=CC=CC=C2C1O    9   10
# 2        4693933                           C1=CC(=CC=C1CC(=O)[O-])O    8    7
# 3            312                                              [Cl-]    0    0
# 4       24772978  CC(C(=O)[O-])OC1C(C(OC(C1O)CO)OP(=O)([O-])OP(=...   20   28
# 5           5753       CC12CCC(=O)C=C1CCC3C2C(CC4(C3CCC4C(=O)CO)C)O   21   30
# 6         253994               COC1=C(C=C(C=C1)CNCCC2=CC=C(C=C2)O)O   16   19
# 7            402                                                  S    0    2
# 8           1099                                      [O-]S(=O)[O-]    0    0
# 9       49791983  C(CC(C(=O)[O-])[NH2+]C(CCC(=O)[O-])C(=O)[O-])C...   11   19
# 10        439339                   CC12CCCCC1CCC3C2CCC4(C3CCC4CCO)C   21   36
# 11          5054                                  C1=CC(=CC(=C1)O)O    6    6
# 12         11318                          C1=CC=C2C(=C1)C=CC(=C2O)O   10    8
# 13       6971056                                C[NH+](C)CC(=O)[O-]    4    9
# 14      57339212  CC(=O)NC1C(C(C(OC1OP(=O)([O-])OP(=O)([O-])OCC2...   17   22
# 15      46878579     C(CC(=O)NC(CS)C(=O)NCC(=O)N)C(C(=O)[O-])[NH3+]   10   18
# 16        101121                              CC(C(=O)C1=CC=CC=C1)O    9   10
# 17           783                                               [HH]    0    1
# 18      11865000       C[NH+]1C2CC(CC1C(C2)O)OC(=O)C(CO)C3=CC=CC=C3   17   24
# 19        164533                        C(CC(=O)[O-])C(=O)C(=O)[O-]    5    4
# 20         13712                      C1C(C(OC1N2C=CC(=O)NC2=O)CO)O    9   12
# 21        164533                        C(CC(=O)[O-])C(=O)C(=O)[O-]    5    4
# 22       5371769                         C1=CC=C2C(=C1)C(=CN2)CC=NO   10   10
# 23      90658393  C1C(C(C(C(C1[NH3+])OC2C(C(C(C(O2)CO)O)O)[NH3+]...   23   48
# 24       5280489  CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC=CC=C(C)C=CC=...   40   56
# 25       6857680                      C(C(C(C(C(C(=O)[O-])O)O)O)O)O    6   11
# 26          8405                                C1=CC=C2C=NC=CC2=C1    9    7
# 27        164533                        C(CC(=O)[O-])C(=O)C(=O)[O-]    5    4
# 28       5460183  CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)CO)OP(=O)([O...   62   88
# 29      45480537  CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3N2)CC(C(C(C...   17   22
# ...          ...                                                ...  ...  ...
# 16981  122706043  CCCCCCC=CCCCCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)C...   35   56
# 16982    7048685                          C(C(COP(=O)([O-])[O-])O)O    3    7
# 16983    5459993                        CC(CC(=O)[O-])(CC(=O)[O-])O    6    8
# 16984  126961143  CCC=CCC1C(CCC1=O)CC(CC(=O)SCCNC(=O)CCNC(=O)C(C...   35   52
# 16985   11459958          C1=CC(=CC=C1C2C(OC3=C(C2=O)C=CC(=C3)O)O)O   15   12
# 16986       1050                             CC1=NC=C(C(=C1O)C=O)CO    8    9
# 16987    5324282                                          CC(C)C=NO    4    9
# 16988       7363                                      C1=COC(=C1)CS    5    6
# 16989   90658148  CCC1C(C=C(C=CC(=O)C(CC(C(C(C(CC(=O)O1)O)C)OC2C...   31   54
# 16990        887                                                 CO    1    4
# 16991   90658148  CCC1C(C=C(C=CC(=O)C(CC(C(C(C(CC(=O)O1)O)C)OC2C...   31   54
# 16992     105034                                         C(=[N-])=O    1    0
# 16993   44237185  CC1=CC(=CC(=C1O)CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C...   52   80
# 16994  131841443  CC(=CCCC(=CCCC(=CCCC(=O)C)C)C)CCC=C(C)CCC=C(C)...   30   48
# 16995   25202620  C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)([O-])OP(=O...   15   19
# 16996      92092                            C(C(C(C(C(=O)CO)O)O)O)O    6   12
# 16997    6971050                            CC(C(C(=O)[O-])[NH3+])O    4    9
# 16998   21125569  C1C(C(OC1N2C=NC3=C2N=CN=C3N)COP(=O)([O-])OP(=O...   10   12
# 16999     440386                        CC(C(C)O)C(=O)OCC1=CC=CC=C1   12   16
# 17000    6971047                            C1CC([NH2+]C1)C(=O)[O-]    5    9
# 17001       7416                          C1=CC=C(C=C1)[N+](=O)[O-]    6    5
# 17002   86289103  CC(C(=O)NC(CCC(=O)NC(CCCC[NH3+])C(=O)NC(C)C(=O...   40   62
# 17003   92136136  C1C(=CC=CN1C2C(C(C(O2)COP(=O)([O-])OP(=O)([O-]...   21   26
# 17004   25244337  C1(C(C(C(C(C1OP(=O)([O-])[O-])OP(=O)([O-])[O-]...    6    8
# 17005   14293614                              C1=CC(=CC=C1C(C#N)O)O    8    7
# 17006   25246060  CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=...   60   97
# 17007    4269236                C1(=C(C(=C(C(=C1Cl)Cl)Cl)Cl)Cl)[O-]    6    0
# 17008     176951                                   C1=CC(C(C=C1)O)O    6    8
# 17009   50986193  CC1=C(C(=C(C=C1O)OC)O)CC=C(C)CCC=C(C)CCC=C(C)C...   53   82
# 17010    5460312              C=C(C(=O)[O-])OC1C=C(C=CC1O)C(=O)[O-]   10    8
#
#        n_O  n_N  n_P  n_S  n_X  n_DoU        MW
# 0        2    0    0    0    0      2   170.252
# 1        1    0    0    0    0      5   134.178
# 2        3    0    0    0    0      5   151.141
# 3        0    0    0    0    1      0    35.453
# 4       19    3    2    0    0      9   676.394
# 5        4    0    0    0    0      7   346.467
# 6        3    1    0    0    0      8   273.332
# 7        0    0    0    1    0      0    34.083
# 8        3    0    0    1    0      1    80.064
# 9        6    4    0    0    0      4   303.295
# 10       1    0    0    0    0      4   304.518
# 11       2    0    0    0    0      4   110.112
# 12       2    0    0    0    0      7   160.172
# 13       2    1    0    0    0      1   103.121
# 14      18    3    2    0    0      9   618.314
# 15       5    4    0    1    0      4   306.344
# 16       2    0    0    0    0      5   150.177
# 17       0    0    0    0    0      0     2.016
# 18       4    1    0    0    0      6   306.382
# 19       5    0    0    0    0      4   144.082
# 20       5    2    0    0    0      5   228.204
# 21       5    0    0    0    0      4   144.082
# 22       1    2    0    0    0      7   174.203
# 23      15    4    0    0    0      2   620.650
# 24       0    0    0    0    0     13   536.888
# 25       7    0    0    0    0      1   195.147
# 26       0    1    0    0    0      7   129.162
# 27       5    0    0    0    0      4   144.082
# 28      14   13    1    0    0     26  1329.370
# 29       6    4    0    0    0      9   378.385
# ...    ...  ...  ...  ...  ...    ...       ...
# 16981   17    7    3    1    0     13   971.854
# 16982    6    0    1    0    0      1   170.057
# 16983    5    0    0    0    0      3   160.125
# 16984   19    7    3    1    0     15   999.820
# 16985    5    0    0    0    0     10   272.256
# 16986    3    1    0    0    0      5   167.164
# 16987    1    1    0    0    0      1    87.122
# 16988    1    0    0    1    0      3   114.169
# 16989    9    1    0    0    0      5   584.771
# 16990    1    0    0    0    0      0    32.042
# 16991    9    1    0    0    0      5   584.771
# 16992    1    1    0    0    0      2    42.017
# 16993    2    0    0    0    0     13   737.210
# 16994    2    0    0    0    0      7   440.712
# 16995   18    2    2    0    0      8   577.261
# 16996    6    0    0    0    0      1   180.156
# 16997    3    1    0    0    0      1   119.120
# 16998    9    5    2    0    0      8   408.180
# 16999    3    0    0    0    0      5   208.257
# 17000    2    1    0    0    0      2   115.132
# 17001    2    1    0    0    0      5   123.111
# 17002   26    9    2    0    0     15  1146.921
# 17003   17    7    3    0    0     14   741.393
# 17004   18    0    4    0    0      5   492.008
# 17005    2    1    0    0    0      6   149.149
# 17006    7    0    2    0    0     13   992.377
# 17007    1    0    0    0    5      4   265.330
# 17008    2    0    0    0    0      3   112.128
# 17009    3    0    0    0    0     13   767.236
# 17010    6    0    0    0    0      7   224.168
#
# [17011 rows x 14 columns]

# %%
df_result.to_csv('../../../big-datasets/master_df_featurized.csv', index=False)

# %%
loaded = pd.read_csv('../../../big-datasets/master_df_featurized.csv')
loaded.head()
# Out:
#           enzyme                 product  reacts  PubChemID  \
# 0   EC-1.1.1.321                 CPD-685     1.0    5363397
# 1   EC-1.1.1.111               1-INDANOL     1.0      22819
# 2  EC-1.21.99.M2  4-HYDROXYPHENYLACETATE     1.0    4693933
# 3  EC-1.21.99.M2                     CL-     1.0        312
# 4    EC-1.3.1.97    UDP-N-ACETYLMURAMATE     1.0   24772978
#
#                                               SMILES  n_C  n_H  n_O  n_N  n_P  \
# 0                                 CC(=CCO)CCC=C(C)CO   10   18    2    0    0
# 1                                  C1CC2=CC=CC=C2C1O    9   10    1    0    0
# 2                           C1=CC(=CC=C1CC(=O)[O-])O    8    7    3    0    0
# 3                                              [Cl-]    0    0    0    0    0
# 4  CC(C(=O)[O-])OC1C(C(OC(C1O)CO)OP(=O)([O-])OP(=...   20   28   19    3    2
#
#    n_S  n_X  n_DoU       MW
# 0    0    0      2  170.252
# 1    0    0      5  134.178
# 2    0    0      5  151.141
# 3    0    1      0   35.453
# 4    0    0      9  676.394

# %%
unique = loaded.groupby('reacts')['enzyme'].nunique()

# %%
unique
# Out:
# reacts
# 0.0    4626
# 1.0    4952
# Name: enzyme, dtype: int64
